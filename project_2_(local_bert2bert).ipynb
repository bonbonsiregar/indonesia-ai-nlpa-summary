# %% [markdown]
# ## 1) Environment Setup
# Prepare local project paths and install required libraries.

# %%
# !nvidia-smi
# Out:
# Fri Apr 10 14:00:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5070 Ti     Off |   00000000:01:00.0 Off |                  N/A |
# | 30%   21C    P8              9W /  300W |      30MiB /  16303MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1971      G   /usr/bin/gnome-shell                      6MiB |
# |    0   N/A  N/A            2429      G   /usr/bin/Xwayland                         4MiB |
# +-----------------------------------------------------------------------------------------+

# %%
from pathlib import Path

PROJECT_ROOT = Path(r'/home/ridwan/Documents/indonesia-ai-nlpa-summary')
ARCHIVE_PATH = Path(r'/home/ridwan/Documents/indonesia-ai-nlpa-summary/liputan6_data.tar.gz')

print(f"Project root: {PROJECT_ROOT}")
print(f"Archive path: {ARCHIVE_PATH}")

if not ARCHIVE_PATH.exists():
    raise FileNotFoundError(f"Archive not found at {ARCHIVE_PATH}")
# Out:
# Project root: /home/ridwan/Documents/indonesia-ai-nlpa-summary
# Archive path: /home/ridwan/Documents/indonesia-ai-nlpa-summary/liputan6_data.tar.gz

# %%
# %pip install -q transformers datasets evaluate rouge_score bert_score "accelerate>=1.1.0"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2) Data Extraction and Sampling
# Extract raw data, refresh destination folders, and build train/dev/test samples.

# %%
import os
import shutil
import tarfile

temp_extract_path = PROJECT_ROOT / '_temp_liputan6_extract'

if temp_extract_path.exists():
    shutil.rmtree(temp_extract_path)
temp_extract_path.mkdir(parents=True, exist_ok=True)

print(f"Extracting canonical data from {ARCHIVE_PATH} to {temp_extract_path}...")
with tarfile.open(ARCHIVE_PATH, "r:gz") as tar:
    canonical_members = [member for member in tar.getmembers() if member.name.startswith("liputan6_data/canonical/")]
    tar.extractall(path=temp_extract_path, members=canonical_members)
print("Temporary extraction finished.")
# Out:
# Extracting canonical data from /home/ridwan/Documents/indonesia-ai-nlpa-summary/liputan6_data.tar.gz to /home/ridwan/Documents/indonesia-ai-nlpa-summary/_temp_liputan6_extract...
# Temporary extraction finished.

# %%
import shutil

sampled_extract_path = PROJECT_ROOT / 'liputan6_data'

print(f"Deleting old sampled folder at {sampled_extract_path}...")
if sampled_extract_path.exists():
    shutil.rmtree(sampled_extract_path)
    print("Old folder successfully deleted.")
else:
    print("Old folder does not exist.")

(sampled_extract_path / 'canonical').mkdir(parents=True, exist_ok=True)
print(f"Created fresh directory at {sampled_extract_path / 'canonical'}")
# Out:
# Deleting old sampled folder at /home/ridwan/Documents/indonesia-ai-nlpa-summary/liputan6_data...
# Old folder successfully deleted.
# Created fresh directory at /home/ridwan/Documents/indonesia-ai-nlpa-summary/liputan6_data/canonical

# %%
import os
import random
import shutil

# Configuration
TOTAL_FILES_TO_SAMPLE = 25000
train_ratio = 0.70
dev_ratio = 0.10
test_ratio = 0.20

# Paths
local_base_path = temp_extract_path / 'liputan6_data' / 'canonical'
sampled_base_path = sampled_extract_path / 'canonical'

# Calculate counts
train_count = int(TOTAL_FILES_TO_SAMPLE * train_ratio)
dev_count = int(TOTAL_FILES_TO_SAMPLE * dev_ratio)
test_count = TOTAL_FILES_TO_SAMPLE - train_count - dev_count # Ensure it adds up exactly

splits = {
    'train': train_count,
    'dev': dev_count,
    'test': test_count
}

print(f"Target distribution -> Train: {train_count}, Dev: {dev_count}, Test: {test_count}\n")

for split, count in splits.items():
    src_dir = local_base_path / split
    dst_dir = sampled_base_path / split

    dst_dir.mkdir(parents=True, exist_ok=True)

    if src_dir.exists():
        all_files = [f for f in os.listdir(src_dir) if f.endswith('.json')]
        print(f"Found {len(all_files)} files in local {split} folder.")

        files_to_copy = random.sample(all_files, min(count, len(all_files)))

        print(f"Copying {len(files_to_copy)} files to local sampled {split} folder...")
        for f in files_to_copy:
            shutil.copy2(src_dir / f, dst_dir / f)
        print(f"Finished copying {split}.\n")
    else:
        print(f"Warning: Source directory {src_dir} not found!")

print(f"Sampling and copying process completed. Sampled data is available at {sampled_base_path}")
# Out:
# Target distribution -> Train: 17500, Dev: 2500, Test: 5000
#
# Found 193883 files in local train folder.
# Copying 17500 files to local sampled train folder...
# Finished copying train.
#
# Found 10972 files in local dev folder.
# Copying 2500 files to local sampled dev folder...
# Finished copying dev.
#
# Found 10972 files in local test folder.
# Copying 5000 files to local sampled test folder...
# Finished copying test.
#
# Sampling and copying process completed. Sampled data is available at /home/ridwan/Documents/indonesia-ai-nlpa-summary/liputan6_data/canonical

# %% [markdown]
# ## 3) Data Sanity Check
# Inspect one sample file to verify schema and content shape.

# %%
import os
import json

sample_dir = PROJECT_ROOT / 'liputan6_data' / 'canonical' / 'train'

if sample_dir.exists():
    sample_files = [f for f in os.listdir(sample_dir) if f.endswith('.json')]
    if sample_files:
        sample_file_path = sample_dir / sample_files[0]
        print(f"Reading sample file: {sample_file_path}\n")

        with open(sample_file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)

        print("JSON Keys:", list(data.keys()))
        print("\nFull JSON Content:")
        print(json.dumps(data, indent=2, ensure_ascii=False))
    else:
        print("No JSON files found in the directory.")
else:
    print(f"Directory not found: {sample_dir}")
# Out:
# Reading sample file: /home/ridwan/Documents/indonesia-ai-nlpa-summary/liputan6_data/canonical/train/147783.json
#
# JSON Keys: ['id', 'url', 'clean_article', 'clean_summary', 'extractive_summary']
#
# Full JSON Content:
# {
#   "id": 147783,
#   "url": "https://www.liputan6.com/news/read/147783/berkeliaran-saat-jam-kerja--puluhan-pns-diciduk",
#   "clean_article": [
#     [
#       "Liputan6",
#       ".",
#       "com",
#       ",",
#       "Cianjur",
#       ":",
#       "Puluhan",
#       "pegawai",
#       "negeri",
#       "sipil",
#       "(",
#       "PNS",
#       ")",
#       "di",
#       "lingkungan",
#       "Kabupaten",
#       "Cianjur",
#       ",",
#       "Jawa",
#       "Barat",
#       ",",
#       "belum",
#       "lama",
#       "ini",
#       "terjaring",
#       "razia",
#       "Satuan",
#       "Polisi",
#       "Pamong",
#       "Praja",
#       "setempat",
#       "."
#     ],
#     [
#       "Mereka",
#       "diciduk",
#       "petugas",
#       "saat",
#       "berada",
#       "di",
#       "luar",
#       "kantor",
#       "pada",
#       "jam",
#       "kerja",
#       "."
#     ],
#     [
#       "Dalam",
#       "penertiban",
#       "itu",
#       ",",
#       "petugas",
#       "Satuan",
#       "Polisi",
#       "Pamong",
#       "Praja",
#       "menghentikan",
#       "laju",
#       "sebuah",
#       "sepeda",
#       "motor",
#       "yang",
#       "dikendarai",
#       "seorang",
#       "pegawai",
#       "negeri",
#       "sipil",
#       "."
#     ],
#     [
#       "Petugas",
#       "pun",
#       "menanyakan",
#       "alasan",
#       "pegawai",
#       "yang",
#       "terjaring",
#       "berada",
#       "di",
#       "tempat",
#       "tersebut",
#       "dan",
#       "bukannya",
#       "bekerja",
#       "di",
#       "kantor",
#       "mereka",
#       "."
#     ],
#     [
#       "Mereka",
#       "yang",
#       "tak",
#       "dapat",
#       "menunjukkan",
#       "surat",
#       "tugas",
#       "langsung",
#       "didata",
#       "dan",
#       "diberi",
#       "peringatan",
#       "agar",
#       "tidak",
#       "mengulangi",
#       "perbuatannya",
#       "."
#     ],
#     [
#       "Pengendara",
#       "sepeda",
#       "motor",
#       "berpelat",
#       "merah",
#       "yang",
#       "bukan",
#       "PNS",
#       "juga",
#       "tak",
#       "luput",
#       "dari",
#       "razia",
#       "petugas",
#       "."
#     ],
#     [
#       "Hingga",
#       "akhir",
#       "razia",
#       ",",
#       "ada",
#       "puluhan",
#       "pegawai",
#       "terjaring",
#       "."
#     ],
#     [
#       "Data",
#       "diri",
#       "para",
#       "PNS",
#       "yang",
#       "terjaring",
#       "selanjutnya",
#       "akan",
#       "disampaikan",
#       "ke",
#       "Kantor",
#       "Badan",
#       "Pengawas",
#       "Daerah",
#       "untuk",
#       "ditindaklanjuti",
#       ".",
#       "(",
#       "ANS/Asep",
#       "Didi",
#       ")",
#       "."
#     ]
#   ],
#   "clean_summary": [
#     [
#       "Petugas",
#       "menanyakan",
#       "alasan",
#       "pegawai",
#       "yang",
#       "terjaring",
#       "berada",
#       "di",
#       "tempat",
#       "tersebut",
#       "dan",
#       "bukannya",
#       "bekerja",
#       "di",
#       "kantor",
#       "mereka",
#       "."
#     ],
#     [
#       "Data",
#       "diri",
#       "para",
#       "PNS",
#       "yang",
#       "terjaring",
#       "selanjutnya",
#       "akan",
#       "disampaikan",
#       "ke",
#       "Kantor",
#       "Badan",
#       "Pengawas",
#       "Daerah",
#       "untuk",
#       "ditindaklanjuti",
#       "."
#     ]
#   ],
#   "extractive_summary": [
#     3,
#     7
#   ]
# }

# %% [markdown]
# ## 4) Load, Structure, and N-gram EDA
# Load JSON files into pandas DataFrames for each split, then run n-gram exploratory analysis to pick a better `no_repeat_ngram_size`.

# %%
import os
import json
import pandas as pd
from tqdm.notebook import tqdm

def load_data_split(split_path):
    records = []
    if not os.path.exists(split_path):
        print(f"Path not found: {split_path}")
        return pd.DataFrame()

    files = [f for f in os.listdir(split_path) if f.endswith('.json')]
    for f in tqdm(files, desc=f"Loading {os.path.basename(split_path)}"):
        with open(os.path.join(split_path, f), 'r', encoding='utf-8') as file:
            data = json.load(file)

            article = ' '.join([' '.join(sentence) for sentence in data.get('clean_article', [])])
            summary = ' '.join([' '.join(sentence) for sentence in data.get('clean_summary', [])])

            records.append({
                'id': data.get('id'),
                'url': data.get('url'),
                'article': article,
                'summary': summary,
                'extractive_summary': data.get('extractive_summary')
            })

    return pd.DataFrame(records)

base_dir = PROJECT_ROOT / 'liputan6_data' / 'canonical'

print("Loading datasets into Pandas DataFrames...")
df_train = load_data_split(base_dir / 'train')
df_dev = load_data_split(base_dir / 'dev')
df_test = load_data_split(base_dir / 'test')

print("\nData Loading Complete!")
print(f"Train size: {len(df_train)}")
print(f"Dev size: {len(df_dev)}")
print(f"Test size: {len(df_test)}")

display(df_train.head(10))
# Out:
# Loading datasets into Pandas DataFrames...
# Loading train:   0%|          | 0/17500 [00:00<?, ?it/s]
# Loading dev:   0%|          | 0/2500 [00:00<?, ?it/s]
# Loading test:   0%|          | 0/5000 [00:00<?, ?it/s]
# Data Loading Complete!
# Train size: 17500
# Dev size: 2500
# Test size: 5000
#        id                                                url  \
# 0  147783  https://www.liputan6.com/news/read/147783/berk...
# 1   45927  https://www.liputan6.com/news/read/45927/nasab...
# 2  296487  https://www.liputan6.com/news/read/296487/madr...
# 3  128609  https://www.liputan6.com/news/read/128609/peny...
# 4  263739  https://www.liputan6.com/news/read/263739/pulu...
# 5   90527  https://www.liputan6.com/news/read/90527/impar...
# 6   42178  https://www.liputan6.com/news/read/42178/empat...
# 7  171222  https://www.liputan6.com/news/read/171222/empa...
# 8  169512  https://www.liputan6.com/news/read/169512/banj...
# 9   88746  https://www.liputan6.com/news/read/88746/abdul...
#
#                                              article  \
# 0  Liputan6 . com , Cianjur : Puluhan pegawai neg...
# 1  Liputan6 . com , Bandung : Sudah menjadi peman...
# 2  Liputan6 . com , Madrid : Real Madrid tidak me...
# 3  Liputan6 . com , Jakarta : Menteri Negara Pere...
# 4  Liputan6 . com , Kediri : Jelang Muktamar Nahd...
# 5  Liputan6 . com , Jakarta : Tak ada kata terlam...
# 6  Liputan6 . com , Maluku Utara : Kasus perusaka...
# 7  Liputan6 . com , Cimahi : Empat remaja mendata...
# 8  Liputan6 . com , Aceh Selatan : Banjir merenda...
# 9  Liputan6 . com , Jakarta : Sejumlah pengamat h...
#
#                                              summary extractive_summary
# 0  Petugas menanyakan alasan pegawai yang terjari...             [3, 7]
# 1  Menjelang Lebaran , nasabah pegadaian bisa dip...             [2, 8]
# 2  Real Madrid memulai fase penyisihan grup Liga ...             [0, 1]
# 3  Menneg Perencanaan Pembangunan Nasional/Kepala...             [0, 1]
# 4  Jelang Muktamar NU , puluhan kiai se-Jawa Madu...             [0, 4]
# 5  Suciwati menanti kesungguhan Presiden untuk me...            [5, 61]
# 6  Empat dari 33 anggota pasukan kilat yang diyak...             [1, 3]
# 7  Mereka mengaku sebagai korban penculikan dan p...          [1, 2, 4]
# 8  Derasnya curah hujan menyebabkan luapan air Su...             [0, 2]
# 9  Jaksa Agung Abdul Rahman Saleh menghadapi bany...             [4, 5]

# %%
from collections import Counter

# N-gram EDA on reference summaries to guide no_repeat_ngram_size

def tokenize_simple(text):
    return [tok for tok in str(text).lower().split() if tok.strip()]

def ngrams(tokens, n):
    return [tuple(tokens[i:i+n]) for i in range(len(tokens) - n + 1)]

def top_ngrams(corpus_series, n, top_k=20):
    counter = Counter()
    for txt in corpus_series:
        toks = tokenize_simple(txt)
        counter.update(ngrams(toks, n))
    return counter.most_common(top_k)

def repeated_ngram_ratio(corpus_series, n):
    repeated = 0
    valid = 0
    for txt in corpus_series:
        toks = tokenize_simple(txt)
        ng = ngrams(toks, n)
        if not ng:
            continue
        valid += 1
        c = Counter(ng)
        if any(v > 1 for v in c.values()):
            repeated += 1
    return (repeated / valid) if valid else 0.0

summary_corpus = df_train['summary'].dropna()
print('N-gram EDA on training summaries')

for n in [2, 3, 4]:
    ratio = repeated_ngram_ratio(summary_corpus, n)
    print(f'  Repeated {n}-gram in same summary: {ratio*100:.2f}%')

for n in [2, 3, 4]:
    print(f'\nTop {n}-grams in summaries:')
    for gram, freq in top_ngrams(summary_corpus, n, top_k=15):
        print(f"  {' '.join(gram):45s} {freq}")

# Heuristic: use smallest n where repeated n-gram ratio <= 5%
threshold = 0.05
recommended_no_repeat_ngram_size = 4
for n in [2, 3, 4]:
    if repeated_ngram_ratio(summary_corpus, n) <= threshold:
        recommended_no_repeat_ngram_size = n
        break

print('\nRecommended no_repeat_ngram_size (from EDA):', recommended_no_repeat_ngram_size)
# Out:
# N-gram EDA on training summaries
#   Repeated 2-gram in same summary: 20.57%
#   Repeated 3-gram in same summary: 3.70%
#   Repeated 4-gram in same summary: 0.66%
#
# Top 2-grams in summaries:
#   . .                                           1004
#   . mereka                                      785
#   , dan                                         748
#   , jawa                                        615
#   ini .                                         597
#   , jatim                                       485
#   . namun                                       480
#   , jakarta                                     478
#   , jabar                                       405
#   . di                                          404
#   ) .                                           404
#   di kawasan                                    402
#   , jateng                                      400
#   ini ,                                         375
#   tersebut .                                    358
#
# Top 3-grams in summaries:
#   . . .                                         511
#   , jatim ,                                     285
#   , jateng ,                                    272
#   . namun ,                                     260
#   , jabar ,                                     255
#   , jawa barat                                  241
#   , jawa tengah                                 188
#   , jawa timur                                  181
#   , jatim .                                     164
#   , banten ,                                    154
#   susilo bambang yudhoyono                      142
#   jawa barat ,                                  129
#   , jabar .                                     119
#   jawa timur ,                                  113
#   jawa tengah ,                                 112
#
# Top 4-grams in summaries:
#   , jawa barat ,                                126
#   , jawa timur ,                                108
#   presiden susilo bambang yudhoyono             105
#   , jawa tengah ,                               105
#   , jawa barat .                                81
#   . sementara itu ,                             76
#   , jawa tengah .                               61
#   , jakarta selatan ,                           55
#   , tangerang , banten                          55
#   ada korban jiwa dalam                         54
#   semarang , jateng ,                           52
#   . meski demikian ,                            50
#   , jawa timur .                                50
#   bandung , jabar ,                             48
#   surabaya , jatim ,                            48
#
# Recommended no_repeat_ngram_size (from EDA): 3

# %% [markdown]
# ### 4b) Novel N-gram Ratio on Reference Summaries
# Measure how much wording in the human summary does **not** appear in the source article. This is a simple abstractiveness proxy: higher novel n-gram ratios mean the summary uses more new phrasing rather than copying directly from the article.

# %%
# Novel n-gram ratio: fraction of summary n-grams that do not appear in the source article

def novel_ngram_ratio(article_text, summary_text, n):
    article_tokens = tokenize_simple(article_text)
    summary_tokens = tokenize_simple(summary_text)

    summary_ngrams = ngrams(summary_tokens, n)
    if not summary_ngrams:
        return np.nan

    article_ngram_set = set(ngrams(article_tokens, n))
    novel_count = sum(1 for gram in summary_ngrams if gram not in article_ngram_set)
    return novel_count / len(summary_ngrams)

print('Novel n-gram ratio on training reference summaries vs. source articles')

novel_ratio_stats = {}
for n in [1, 2, 3, 4]:
    ratios = [
        novel_ngram_ratio(article, summary, n)
        for article, summary in zip(df_train['article'], df_train['summary'])
        if pd.notna(article) and pd.notna(summary)
    ]
    ratios = pd.Series(ratios).dropna()
    novel_ratio_stats[n] = ratios.mean()
    print(f'  Novel {n}-gram ratio: {ratios.mean()*100:.2f}%')

print('\nInterpretation: higher values indicate more abstractive reference summaries.')
# Out:
# Novel n-gram ratio on training reference summaries vs. source articles
#   Novel 1-gram ratio: 12.40%
#   Novel 2-gram ratio: 40.36%
#   Novel 3-gram ratio: 56.02%
#   Novel 4-gram ratio: 65.20%
#
# Interpretation: higher values indicate more abstractive reference summaries.

# %% [markdown]
# ## 5) Tokenization and Preprocessing
# Convert DataFrames to Hugging Face datasets and tokenize inputs/targets.

# %%
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer

# Convert Pandas DataFrames to Hugging Face Datasets
raw_datasets = DatasetDict({
    "train": Dataset.from_pandas(df_train),
    "validation": Dataset.from_pandas(df_dev),
    "test": Dataset.from_pandas(df_test)
})

# We use a BERT2BERT model tailored for Indonesian text summarization
model_checkpoint = "cahya/bert2bert-indonesian-summarization"

print(f"Loading tokenizer from {model_checkpoint}...")
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# Set max lengths for the articles and the summaries
max_input_length = 512
max_target_length = 128

def preprocess_function(examples):
    inputs = examples["article"]
    targets = examples["summary"]

    # Tokenize the input articles
    model_inputs = tokenizer(inputs, max_length=max_input_length, padding="max_length", truncation=True)

    # Tokenize the target summaries
    labels = tokenizer(targets, max_length=max_target_length, padding="max_length", truncation=True)

    # Replace the padding token id with -100 so they are ignored by the loss function
    labels["input_ids"] = [
        [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in labels["input_ids"]
    ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

print("Tokenizing datasets... This might take a minute.")
tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
print("\nTokenization complete!")

# Preview the keys of the first tokenized train record to ensure it contains 'input_ids' and 'labels'
print("\nFeatures in our tokenized dataset:", list(tokenized_datasets["train"][0].keys()))
# Out:
# Loading tokenizer from cahya/bert2bert-indonesian-summarization...
# Tokenizing datasets... This might take a minute.
# Map:   0%|          | 0/17500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Tokenization complete!
#
# Features in our tokenized dataset: ['id', 'url', 'article', 'summary', 'extractive_summary', 'input_ids', 'token_type_ids', 'attention_mask', 'labels']

# %% [markdown]
# ## 6) Extractive Baseline Evaluation (Comparable Protocol)
# Evaluate extractive summaries using the same protocol as the comparison table:
# - prediction: extractive summary reconstructed from index pointers into `clean_article`
# - target: human abstractive summary (`clean_summary`)
# - split/subset: 250-sample test subset (fixed seed)
# - report: ROUGE-1/2/L precision, recall, and F1

# %%
from rouge_score import rouge_scorer

scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=False)

scores = scorer.score(
    target="Liputan6 . com , Jakarta : Artis Ussy Sulistiawaty mengaku sedikit mengerem kegiatan di bulan suci Ramadan . Tujuannya demi menjaga kondisi tubuh yang belakangan rentan terhadap penyakit . \" Rada dikurangi saja , sekarang lebih fokus sama rekaman buat album ketiga , \"ujar Ussy di Hot Shot SCTV , Ahad ( 29/8 ) . Ussy saat ini berada pada kondisi 90 persen fit . Ussy yang pada saat itu ditemani sang kekasih , Andika Pratama berencana meluncurkan album terbaru setelah Lebaran . Pelantun tembang Klik itu berharap deretan lagu barunya mampu memikat hati para pecinta musik Tanah Air . Sebelumnya Ussy dan Andika berkomitmen hanya bertemu setelah berbuka puasa . Itu semua dilakukan demi menghindari hal negatif yang dapat merusak ibadah mereka [ baca : Andhika-Ussy Bicara Soal Makna Puasa ] . ( AIS ) .",
    prediction="Ussy Sulistiawaty mengaku sedikit mengerem kegiatan di bulan Ramadan untuk menjaga kondisi tubuh ."
)

print(scores)
# Out:
# {'rouge1': Score(precision=0.9230769230769231, recall=0.10434782608695652, fmeasure=0.18749999999999997), 'rouge2': Score(precision=0.75, recall=0.07894736842105263, fmeasure=0.14285714285714285), 'rougeL': Score(precision=0.9230769230769231, recall=0.10434782608695652, fmeasure=0.18749999999999997)}

# %%
import json
import numpy as np
import pandas as pd
from rouge_score import rouge_scorer

scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=False)

EVAL_SAMPLE_SIZE = 250
EVAL_RANDOM_STATE = 42

# Same subset protocol used by the downstream comparison section
subset = df_test.sample(n=EVAL_SAMPLE_SIZE, random_state=EVAL_RANDOM_STATE).reset_index(drop=True)

def _resolve_row_id(raw_id):
    if isinstance(raw_id, (int, np.integer)):
        return str(int(raw_id))
    if isinstance(raw_id, float) and raw_id.is_integer():
        return str(int(raw_id))
    return str(raw_id).strip()

def reconstruct_extractive_from_indices(row_id):
    json_id = _resolve_row_id(row_id)
    json_path = base_dir / 'test' / f'{json_id}.json'

    if not json_path.exists():
        return ''

    with open(json_path, 'r', encoding='utf-8') as f:
        sample = json.load(f)

    clean_article = sample.get('clean_article', [])
    extractive = sample.get('extractive_summary', [])

    if isinstance(extractive, list) and all(isinstance(i, (int, np.integer)) for i in extractive):
        sentence_texts = [
            ' '.join(sent) if isinstance(sent, list) else str(sent)
            for sent in clean_article
        ]
        picked = [sentence_texts[i] for i in extractive if 0 <= i < len(sentence_texts)]
        return ' '.join(picked).strip()

    # Fallback for non-index formats.
    if isinstance(extractive, str):
        return extractive.strip()
    if isinstance(extractive, list):
        chunks = []
        for item in extractive:
            if isinstance(item, list):
                chunks.append(' '.join(str(tok) for tok in item))
            else:
                chunks.append(str(item))
        return ' '.join(part for part in chunks if part).strip()

    return ''

def compute_rouge_extractive(row):
    pred = reconstruct_extractive_from_indices(row['id'])
    scores = scorer.score(target=row['summary'], prediction=pred)

    result = {}
    for m in ['rouge1', 'rouge2', 'rougeL']:
        result[f'{m}_precision'] = scores[m].precision
        result[f'{m}_recall'] = scores[m].recall
        result[f'{m}_fmeasure'] = scores[m].fmeasure
    return pd.Series(result)

rouge_scores = subset.apply(compute_rouge_extractive, axis=1)
df_eval = pd.concat([subset[['id', 'summary']], rouge_scores], axis=1)

cols = [
    'rouge1_precision', 'rouge1_recall', 'rouge1_fmeasure',
    'rouge2_precision', 'rouge2_recall', 'rouge2_fmeasure',
    'rougeL_precision', 'rougeL_recall', 'rougeL_fmeasure'
]

stats_decimal = df_eval[cols].agg(['min', 'max', 'mean']).round(4)
stats_percent = (stats_decimal * 100).round(2)

print(f'Comparable extractive baseline on test subset (n={EVAL_SAMPLE_SIZE}, seed={EVAL_RANDOM_STATE})')
print('\nROUGE stats (0-1 scale):')
print(stats_decimal)
print('\nROUGE stats (% scale, directly comparable to Section 11 table):')
print(stats_percent)
# Out:
# Comparable extractive baseline on test subset (n=250, seed=42)
#
# ROUGE stats (0-1 scale):
#       rouge1_precision  rouge1_recall  rouge1_fmeasure  rouge2_precision  \
# min             0.2286         0.3200           0.2807            0.0222
# max             0.8485         1.0000           0.8750            0.7812
# mean            0.4391         0.6367           0.5126            0.2600
#
#       rouge2_recall  rouge2_fmeasure  rougeL_precision  rougeL_recall  \
# min          0.0435           0.0308            0.1053         0.1250
# max          0.8696           0.8065            0.8485         0.9583
# mean         0.3804           0.3044            0.3544         0.5132
#
#       rougeL_fmeasure
# min            0.1143
# max            0.8750
# mean           0.4134
#
# ROUGE stats (% scale, directly comparable to Section 11 table):
#       rouge1_precision  rouge1_recall  rouge1_fmeasure  rouge2_precision  \
# min              22.86          32.00            28.07              2.22
# max              84.85         100.00            87.50             78.12
# mean             43.91          63.67            51.26             26.00
#
#       rouge2_recall  rouge2_fmeasure  rougeL_precision  rougeL_recall  \
# min            4.35             3.08             10.53          12.50
# max           86.96            80.65             84.85          95.83
# mean          38.04            30.44             35.44          51.32
#
#       rougeL_fmeasure
# min             11.43
# max             87.50
# mean            41.34

# %% [markdown]
# ## 7) Model and Trainer Setup
# Initialize the seq2seq model, metrics, and training arguments.

# %%
from transformers import (
    EncoderDecoderModel,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
    DataCollatorForSeq2Seq,
    EarlyStoppingCallback,
)
import evaluate
import numpy as np
from typing import Any, cast

# 1. Load the model
print(f"Loading model {model_checkpoint}...")
model = EncoderDecoderModel.from_pretrained(model_checkpoint)
# NOTE: Removed tie_word_embeddings=False — the cahya pretrained model was trained
# with tied embeddings; untying them forces the model to relearn the embedding space
# from scratch, which hurts fine-tuning with limited data.

# Resolve n-gram blocking size from EDA (fallback to 3 if EDA cell is skipped)
NO_REPEAT_NGRAM_SIZE = int(globals().get("recommended_no_repeat_ngram_size", 3))
print(f"Using no_repeat_ngram_size={NO_REPEAT_NGRAM_SIZE} (from EDA or fallback)")

# Set model configuration for sequence-to-sequence generation
model.config.decoder_start_token_id = tokenizer.cls_token_id
model.config.eos_token_id = tokenizer.sep_token_id
model.config.pad_token_id = tokenizer.pad_token_id
model.config.vocab_size = model.config.encoder.vocab_size

# Generation parameters — FIXED for proper evaluation
# Key changes vs. original cahya demo config:
#   1. do_sample=False: Use pure beam search for deterministic, higher-quality output.
#      The original do_sample=True + num_beams=10 conflicted (sampling distorts beam scores).
#   2. Removed repetition_penalty=2.5: Too aggressive — suppresses common Indonesian
#      function words after first use, producing fragmented summaries.
#   3. no_repeat_ngram_size=3 (from EDA): Less restrictive than 2, allows natural
#      Indonesian bigram repetition while blocking trigram repetition.
#   4. max_length=150: Matches paper's generation length; 80 was too short.
#   5. num_beams=5: Matches paper's BertExtAbs evaluation protocol.
model.generation_config.max_length = 150
model.generation_config.min_length = 15
model.generation_config.no_repeat_ngram_size = NO_REPEAT_NGRAM_SIZE
model.generation_config.early_stopping = True
model.generation_config.length_penalty = 0.6
model.generation_config.num_beams = 5
model.generation_config.do_sample = False
model.generation_config.decoder_start_token_id = tokenizer.cls_token_id
model.generation_config.eos_token_id = tokenizer.sep_token_id
model.generation_config.pad_token_id = tokenizer.pad_token_id

# 2. Data collator
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# 3. Metric (ROUGE)
rouge_metric = evaluate.load("rouge")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)

    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(pred.strip().split()) for pred in decoded_preds]
    decoded_labels = ["\n".join(label.strip().split()) for label in decoded_labels]

    # NOTE: use_stemmer=False to match the paper's pyrouge evaluation protocol.
    # The paper (AACL 2020) uses pyrouge which does NOT apply stemming.
    # Using use_stemmer=True inflates scores and makes comparison unfair.
    result = rouge_metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=False)

    # Extract a few results
    result = {key: value * 100 for key, value in result.items()}

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)

    return {k: round(v, 4) for k, v in result.items()}

# 4. Training Arguments (anti-overfitting defaults)
# Reduced per-device batch to 16 with gradient_accumulation_steps=2 for
# effective batch size of 32 — more stable than batch_size=32 directly.
batch_size = 16

args = Seq2SeqTrainingArguments(
    output_dir=str(PROJECT_ROOT / "bert2bert-indonesian-summarization-finetuned"),
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="epoch",
    learning_rate=2e-5,
    warmup_steps=500,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    gradient_accumulation_steps=2,  # effective batch = 16 * 2 = 32
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=8,
    predict_with_generate=True,
    generation_max_length=150,  # Match generation config
    generation_num_beams=5,     # Match generation config
    load_best_model_at_end=True,
    metric_for_best_model="eval_rougeL",
    greater_is_better=True,
    fp16=True, # Enable mixed precision for faster training on GPU
    push_to_hub=False,
)

trainer = Seq2SeqTrainer(
    model=model,
    args=args,
    train_dataset=cast(Any, tokenized_datasets["train"]),
    eval_dataset=cast(Any, tokenized_datasets["validation"]),
    data_collator=data_collator,
    # tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]
)

print("Trainer setup complete! Overfitting controls enabled:")
print("- Early stopping patience: 3 eval epochs")
print("- Best model auto-loaded by eval_rougeL")
print("- Warmup steps: 500")
print("- Max epochs: 8")
# Out:
# Loading model cahya/bert2bert-indonesian-summarization...
# Loading weights:   0%|          | 0/523 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie decoder.bert.embeddings.word_embeddings.weight to decoder.cls.predictions.decoder.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie decoder.cls.predictions.bias to decoder.cls.predictions.decoder.bias, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# EncoderDecoderModel LOAD REPORT from: cahya/bert2bert-indonesian-summarization
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# encoder.embeddings.position_ids      | UNEXPECTED |  |
# decoder.bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Using no_repeat_ngram_size=3 (from EDA or fallback)
# Trainer setup complete! Overfitting controls enabled:
# - Early stopping patience: 3 eval epochs
# - Best model auto-loaded by eval_rougeL
# - Warmup steps: 500
# - Max epochs: 8

# %% [markdown]
# ## 8) Pre-fine-tuning Baseline Evaluation
# Generate summaries using the **pre-trained** (not yet fine-tuned) model on a 250-sample subset of the test set.
# This establishes a before/after ROUGE comparison to quantify the benefit of fine-tuning.

# %%
import torch
import numpy as np
from rouge_score import rouge_scorer as rs

BASELINE_SAMPLE_SIZE = 250
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

# Draw a reproducible 250-sample subset from the test set
baseline_sample = df_test.sample(n=BASELINE_SAMPLE_SIZE, random_state=42).reset_index(drop=True)

def generate_summary(text, mdl, tok, max_input=512):
    """Generate summary using pure beam search (paper-matching evaluation protocol).

    Key fixes vs. original cahya demo config:
    - do_sample=False: Pure beam search for deterministic, reproducible output
    - No repetition_penalty: Was too aggressive (2.5), suppressing common Indonesian words
    - no_repeat_ngram_size=3: From EDA, less restrictive than 2
    - max_length=150: Matches paper's generation length
    - num_beams=5: Matches paper's BertExtAbs evaluation protocol
    - length_penalty=0.6: Encourages slightly shorter, more concise summaries
    """
    inputs = tok(
        text,
        max_length=max_input,
        truncation=True,
        return_tensors="pt"
    ).to(device)
    with torch.no_grad():
        output_ids = mdl.generate(
            input_ids=inputs["input_ids"],
            min_length=15,
            max_length=150,
            num_beams=5,
            length_penalty=0.6,
            early_stopping=True,
            no_repeat_ngram_size=NO_REPEAT_NGRAM_SIZE,
            use_cache=True,
            do_sample=False,
        )
    return tok.decode(output_ids[0], skip_special_tokens=True)

print(f"Generating pre-fine-tuning summaries on {BASELINE_SAMPLE_SIZE} test samples...")
print("Decoding config -> pure beam search (num_beams=5, max_length=150, do_sample=False)")
pre_ft_generated = []
for _, row in baseline_sample.iterrows():
    pred = generate_summary(row["article"], model, tokenizer)
    pre_ft_generated.append(pred)
print(f"Done. Generated {len(pre_ft_generated)} summaries.")

# Compute ROUGE on generated summaries vs. reference human summaries
# NOTE: use_stemmer=False to match paper's pyrouge evaluation protocol
scorer_eval = rs.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=False)

agg_pre = {
    "rouge1": {"precision": [], "recall": [], "fmeasure": []},
    "rouge2": {"precision": [], "recall": [], "fmeasure": []},
    "rougeL": {"precision": [], "recall": [], "fmeasure": []}
}

for pred, ref in zip(pre_ft_generated, baseline_sample["summary"].tolist()):
    s = scorer_eval.score(target=ref, prediction=pred)
    for k in agg_pre:
        agg_pre[k]["precision"].append(s[k].precision)
        agg_pre[k]["recall"].append(s[k].recall)
        agg_pre[k]["fmeasure"].append(s[k].fmeasure)

pre_ft_scores_detailed = {
    rouge_name: {
        metric_name: round(float(np.mean(metric_values)) * 100, 4)
        for metric_name, metric_values in metrics_dict.items()
    }
    for rouge_name, metrics_dict in agg_pre.items()
}

# Keep compatibility with downstream comparison cell (uses f-measure only)
pre_ft_scores = {k: v["fmeasure"] for k, v in pre_ft_scores_detailed.items()}

print(f"\n--- Pre-fine-tuning ROUGE Scores (mean %, {BASELINE_SAMPLE_SIZE} test samples) ---")
for rouge_name, metrics_dict in pre_ft_scores_detailed.items():
    print(
        f"  {rouge_name:6s} -> "
        f"precision: {metrics_dict['precision']:.4f}, "
        f"recall: {metrics_dict['recall']:.4f}, "
        f"fmeasure: {metrics_dict['fmeasure']:.4f}"
    )
# Out:
# Generating pre-fine-tuning summaries on 250 test samples...
# Decoding config -> pure beam search (num_beams=5, max_length=150, do_sample=False)
# Done. Generated 250 summaries.
#
# --- Pre-fine-tuning ROUGE Scores (mean %, 250 test samples) ---
#   rouge1 -> precision: 32.1795, recall: 25.4930, fmeasure: 28.0491
#   rouge2 -> precision: 14.3357, recall: 11.1554, fmeasure: 12.3604
#   rougeL -> precision: 27.1825, recall: 21.4531, fmeasure: 23.6405

# %% [markdown]
# ## 8b) BERTScore Evaluation (Pre-fine-tuning)
# Compute **BERTScore** alongside ROUGE to capture semantic similarity that n-gram overlap misses.
# BERTScore uses contextual embeddings to measure how semantically close the generated summary is to the reference, even when they use different words (e.g., synonyms, paraphrases, morphological variants common in Indonesian).

# %%
import bert_score

# Compute BERTScore for pre-fine-tuning generated summaries
# Uses IndoBERT-based model for better Indonesian language understanding
print(f"Computing BERTScore for pre-fine-tuning summaries ({BASELINE_SAMPLE_SIZE} samples)...")
print("Using lang='id' for Indonesian-specific embeddings")

pre_ft_bs = bert_score.score(
    cands=pre_ft_generated,
    refs=baseline_sample["summary"].tolist(),
    lang="id",
    verbose=True,
    batch_size=64,
)

pre_ft_bertscore = {
    "precision": round(float(pre_ft_bs[0].mean()) * 100, 4),
    "recall": round(float(pre_ft_bs[1].mean()) * 100, 4),
    "f1": round(float(pre_ft_bs[2].mean()) * 100, 4),
}

print(f"\n--- Pre-fine-tuning BERTScore (mean %, {BASELINE_SAMPLE_SIZE} test samples) ---")
print(f"  Precision: {pre_ft_bertscore['precision']:.4f}")
print(f"  Recall:    {pre_ft_bertscore['recall']:.4f}")
print(f"  F1:        {pre_ft_bertscore['f1']:.4f}")
# Out:
# Computing BERTScore for pre-fine-tuning summaries (250 samples)...
# Using lang='id' for Indonesian-specific embeddings
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-base-multilingual-cased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/8 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 0.29 seconds, 867.84 sentences/sec
#
# --- Pre-fine-tuning BERTScore (mean %, 250 test samples) ---
#   Precision: 74.8212
#   Recall:    71.9328
#   F1:        73.3238

# %% [markdown]
# ## 9) Fine-tuning
# Fine-tune the BERT2BERT model on the 17,500-sample Indonesian training split.
# After training the model is saved inside the project so it can be reused in future sessions.

# %%
import os

print("Starting fine-tuning...")
train_result = trainer.train()

print("\n--- Training Metrics ---")
print(train_result.metrics)

finetuned_save_path = PROJECT_ROOT / 'bert2bert-indonesian-finetuned'
os.makedirs(finetuned_save_path, exist_ok=True)
trainer.save_model(finetuned_save_path)
tokenizer.save_pretrained(finetuned_save_path)
print(f"\nFine-tuned model saved to: {finetuned_save_path}")
# Out:
# Starting fine-tuning...
# /home/ridwan/anaconda3/envs/pioanaconda/lib/python3.11/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:445: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='2735' max='4376' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2735/4376 25:00 < 15:01, 1.82 it/s, Epoch 5/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.057932</td>
#       <td>2.231192</td>
#       <td>30.984300</td>
#       <td>13.978700</td>
#       <td>26.704000</td>
#       <td>31.007300</td>
#       <td>31.770400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.197308</td>
#       <td>2.257495</td>
#       <td>31.012800</td>
#       <td>13.934500</td>
#       <td>26.906400</td>
#       <td>31.042700</td>
#       <td>32.108400</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.831054</td>
#       <td>2.318516</td>
#       <td>30.806600</td>
#       <td>13.699100</td>
#       <td>26.819100</td>
#       <td>30.814900</td>
#       <td>31.102400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.569071</td>
#       <td>2.359071</td>
#       <td>30.780800</td>
#       <td>13.770200</td>
#       <td>26.799300</td>
#       <td>30.810600</td>
#       <td>31.650800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.377079</td>
#       <td>2.421363</td>
#       <td>30.735000</td>
#       <td>13.701900</td>
#       <td>26.700100</td>
#       <td>30.728200</td>
#       <td>31.467200</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/ridwan/anaconda3/envs/pioanaconda/lib/python3.11/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:445: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/ridwan/anaconda3/envs/pioanaconda/lib/python3.11/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:445: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/ridwan/anaconda3/envs/pioanaconda/lib/python3.11/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:445: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/ridwan/anaconda3/envs/pioanaconda/lib/python3.11/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:445: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# There were missing keys in the checkpoint model loaded: ['encoder.embeddings.LayerNorm.weight', 'encoder.embeddings.LayerNorm.bias', 'encoder.encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.encoder.layer.0.output.LayerNorm.weight', 'encoder.encoder.layer.0.output.LayerNorm.bias', 'encoder.encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.encoder.layer.1.attention.output.LayerNorm.bias', 'encoder.encoder.layer.1.output.LayerNorm.weight', 'encoder.encoder.layer.1.output.LayerNorm.bias', 'encoder.encoder.layer.2.attention.output.LayerNorm.weight', 'encoder.encoder.layer.2.attention.output.LayerNorm.bias', 'encoder.encoder.layer.2.output.LayerNorm.weight', 'encoder.encoder.layer.2.output.LayerNorm.bias', 'encoder.encoder.layer.3.attention.output.LayerNorm.weight', 'encoder.encoder.layer.3.attention.output.LayerNorm.bias', 'encoder.encoder.layer.3.output.LayerNorm.weight', 'encoder.encoder.layer.3.output.LayerNorm.bias', 'encoder.encoder.layer.4.attention.output.LayerNorm.weight', 'encoder.encoder.layer.4.attention.output.LayerNorm.bias', 'encoder.encoder.layer.4.output.LayerNorm.weight', 'encoder.encoder.layer.4.output.LayerNorm.bias', 'encoder.encoder.layer.5.attention.output.LayerNorm.weight', 'encoder.encoder.layer.5.attention.output.LayerNorm.bias', 'encoder.encoder.layer.5.output.LayerNorm.weight', 'encoder.encoder.layer.5.output.LayerNorm.bias', 'encoder.encoder.layer.6.attention.output.LayerNorm.weight', 'encoder.encoder.layer.6.attention.output.LayerNorm.bias', 'encoder.encoder.layer.6.output.LayerNorm.weight', 'encoder.encoder.layer.6.output.LayerNorm.bias', 'encoder.encoder.layer.7.attention.output.LayerNorm.weight', 'encoder.encoder.layer.7.attention.output.LayerNorm.bias', 'encoder.encoder.layer.7.output.LayerNorm.weight', 'encoder.encoder.layer.7.output.LayerNorm.bias', 'encoder.encoder.layer.8.attention.output.LayerNorm.weight', 'encoder.encoder.layer.8.attention.output.LayerNorm.bias', 'encoder.encoder.layer.8.output.LayerNorm.weight', 'encoder.encoder.layer.8.output.LayerNorm.bias', 'encoder.encoder.layer.9.attention.output.LayerNorm.weight', 'encoder.encoder.layer.9.attention.output.LayerNorm.bias', 'encoder.encoder.layer.9.output.LayerNorm.weight', 'encoder.encoder.layer.9.output.LayerNorm.bias', 'encoder.encoder.layer.10.attention.output.LayerNorm.weight', 'encoder.encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.encoder.layer.10.output.LayerNorm.weight', 'encoder.encoder.layer.10.output.LayerNorm.bias', 'encoder.encoder.layer.11.attention.output.LayerNorm.weight', 'encoder.encoder.layer.11.attention.output.LayerNorm.bias', 'encoder.encoder.layer.11.output.LayerNorm.weight', 'encoder.encoder.layer.11.output.LayerNorm.bias', 'decoder.bert.embeddings.LayerNorm.weight', 'decoder.bert.embeddings.LayerNorm.bias', 'decoder.bert.encoder.layer.0.attention.output.LayerNorm.weight', 'decoder.bert.encoder.layer.0.attention.output.LayerNorm.bias', 'decoder.bert.encoder.layer.0.crossattention.output.LayerNorm.weight', 'decoder.bert.encoder.layer.0.crossattention.output.LayerNorm.bias', 'decoder.bert.encoder.layer.0.output.LayerNorm.weight', 'decoder.bert.encoder.layer.0.output.LayerNorm.bias', 'decoder.bert.encoder.layer.1.attention.output.LayerNorm.weight', 'decoder.bert.encoder.layer.1.attention.output.LayerNorm.bias', 'decoder.bert.encoder.layer.1.crossattention.output.LayerNorm.weight', 'decoder.bert.encoder.layer.1.crossattention.output.LayerNorm.bias', 'decoder.bert.encoder.layer.1.output.LayerNorm.weight', 'decoder.bert.encoder.layer.1.output.LayerNorm.bias', 'decoder.bert.encoder.layer.2.attention.output.LayerNorm.weight', 'decoder.bert.encoder.layer.2.attention.output.LayerNorm.bias', 'decoder.bert.encoder.layer.2.crossattention.output.LayerNorm.weight', 'decoder.bert.encoder.layer.2.crossattention.output.LayerNorm.bias', 'decoder.bert.encoder.layer.2.output.LayerNorm.weight', 'decoder.bert.encoder.layer.2.output.LayerNorm. ...
# There were unexpected keys in the checkpoint model loaded: ['encoder.embeddings.LayerNorm.beta', 'encoder.embeddings.LayerNorm.gamma', 'encoder.encoder.layer.0.attention.output.LayerNorm.beta', 'encoder.encoder.layer.0.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.0.output.LayerNorm.beta', 'encoder.encoder.layer.0.output.LayerNorm.gamma', 'encoder.encoder.layer.1.attention.output.LayerNorm.beta', 'encoder.encoder.layer.1.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.1.output.LayerNorm.beta', 'encoder.encoder.layer.1.output.LayerNorm.gamma', 'encoder.encoder.layer.2.attention.output.LayerNorm.beta', 'encoder.encoder.layer.2.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.2.output.LayerNorm.beta', 'encoder.encoder.layer.2.output.LayerNorm.gamma', 'encoder.encoder.layer.3.attention.output.LayerNorm.beta', 'encoder.encoder.layer.3.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.3.output.LayerNorm.beta', 'encoder.encoder.layer.3.output.LayerNorm.gamma', 'encoder.encoder.layer.4.attention.output.LayerNorm.beta', 'encoder.encoder.layer.4.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.4.output.LayerNorm.beta', 'encoder.encoder.layer.4.output.LayerNorm.gamma', 'encoder.encoder.layer.5.attention.output.LayerNorm.beta', 'encoder.encoder.layer.5.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.5.output.LayerNorm.beta', 'encoder.encoder.layer.5.output.LayerNorm.gamma', 'encoder.encoder.layer.6.attention.output.LayerNorm.beta', 'encoder.encoder.layer.6.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.6.output.LayerNorm.beta', 'encoder.encoder.layer.6.output.LayerNorm.gamma', 'encoder.encoder.layer.7.attention.output.LayerNorm.beta', 'encoder.encoder.layer.7.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.7.output.LayerNorm.beta', 'encoder.encoder.layer.7.output.LayerNorm.gamma', 'encoder.encoder.layer.8.attention.output.LayerNorm.beta', 'encoder.encoder.layer.8.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.8.output.LayerNorm.beta', 'encoder.encoder.layer.8.output.LayerNorm.gamma', 'encoder.encoder.layer.9.attention.output.LayerNorm.beta', 'encoder.encoder.layer.9.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.9.output.LayerNorm.beta', 'encoder.encoder.layer.9.output.LayerNorm.gamma', 'encoder.encoder.layer.10.attention.output.LayerNorm.beta', 'encoder.encoder.layer.10.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.10.output.LayerNorm.beta', 'encoder.encoder.layer.10.output.LayerNorm.gamma', 'encoder.encoder.layer.11.attention.output.LayerNorm.beta', 'encoder.encoder.layer.11.attention.output.LayerNorm.gamma', 'encoder.encoder.layer.11.output.LayerNorm.beta', 'encoder.encoder.layer.11.output.LayerNorm.gamma', 'decoder.bert.embeddings.LayerNorm.beta', 'decoder.bert.embeddings.LayerNorm.gamma', 'decoder.bert.encoder.layer.0.attention.output.LayerNorm.beta', 'decoder.bert.encoder.layer.0.attention.output.LayerNorm.gamma', 'decoder.bert.encoder.layer.0.crossattention.output.LayerNorm.beta', 'decoder.bert.encoder.layer.0.crossattention.output.LayerNorm.gamma', 'decoder.bert.encoder.layer.0.output.LayerNorm.beta', 'decoder.bert.encoder.layer.0.output.LayerNorm.gamma', 'decoder.bert.encoder.layer.1.attention.output.LayerNorm.beta', 'decoder.bert.encoder.layer.1.attention.output.LayerNorm.gamma', 'decoder.bert.encoder.layer.1.crossattention.output.LayerNorm.beta', 'decoder.bert.encoder.layer.1.crossattention.output.LayerNorm.gamma', 'decoder.bert.encoder.layer.1.output.LayerNorm.beta', 'decoder.bert.encoder.layer.1.output.LayerNorm.gamma', 'decoder.bert.encoder.layer.2.attention.output.LayerNorm.beta', 'decoder.bert.encoder.layer.2.attention.output.LayerNorm.gamma', 'decoder.bert.encoder.layer.2.crossattention.output.LayerNorm.beta', 'decoder.bert.encoder.layer.2.crossattention.output.LayerNorm.gamma', 'decoder.bert.encoder.layer.2.output.LayerNorm.beta', 'decoder.bert.encoder.layer.2.output.LayerNorm.gamma', 'decoder.bert.encoder.lay ...
# --- Training Metrics ---
# {'train_runtime': 1501.104, 'train_samples_per_second': 93.265, 'train_steps_per_second': 2.915, 'total_flos': 6.02922614784e+16, 'train_loss': 2.0064887177573696, 'epoch': 5.0}
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Fine-tuned model saved to: /home/ridwan/Documents/indonesia-ai-nlpa-summary/bert2bert-indonesian-finetuned

# %% [markdown]
# ## 10) Post-fine-tuning Evaluation
# Evaluate the fine-tuned model in two ways:
#
# 1. **Trainer evaluate** — official ROUGE on the full 5,000-sample tokenized test split (uses `compute_metrics` with `predict_with_generate=True`).
# 2. **Direct inference ROUGE + BERTScore** — run `model.generate()` on the **same 250-sample baseline subset** used in Section 8, so results are directly comparable.

# %%
# 10a. Official Trainer evaluation on the full tokenized test split
print("Running evaluation on the full tokenized test split (5,000 samples)...")
eval_results = trainer.evaluate(tokenized_datasets["test"])
print("\n--- Official Test-set ROUGE (full 5,000 samples) ---")
for k, v in eval_results.items():
    print(f"  {k}: {v}")
# Out:
# Running evaluation on the full tokenized test split (5,000 samples)...
# /home/ridwan/anaconda3/envs/pioanaconda/lib/python3.11/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:445: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='313' max='313' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [313/313 03:47]
#     </div>
# --- Official Test-set ROUGE (full 5,000 samples) ---
#   eval_loss: 1.9865944385528564
#   eval_rouge1: 34.5183
#   eval_rouge2: 16.8284
#   eval_rougeL: 29.7751
#   eval_rougeLsum: 34.529
#   eval_gen_len: 31.7646
#   eval_runtime: 229.4678
#   eval_samples_per_second: 21.79
#   eval_steps_per_second: 1.364
#   epoch: 5.0

# %%
# 10b. Direct inference ROUGE on the same 250-sample baseline subset
print("Generating post-fine-tuning summaries on the same 250 baseline test samples...")
post_ft_generated = []
model.eval()
for _, row in baseline_sample.iterrows():
    pred = generate_summary(row["article"], model, tokenizer)
    post_ft_generated.append(pred)
print(f"Done. Generated {len(post_ft_generated)} summaries.")

agg_post = {
    "rouge1": {"precision": [], "recall": [], "fmeasure": []},
    "rouge2": {"precision": [], "recall": [], "fmeasure": []},
    "rougeL": {"precision": [], "recall": [], "fmeasure": []}
}

for pred, ref in zip(post_ft_generated, baseline_sample["summary"].tolist()):
    s = scorer_eval.score(target=ref, prediction=pred)
    for k in agg_post:
        agg_post[k]["precision"].append(s[k].precision)
        agg_post[k]["recall"].append(s[k].recall)
        agg_post[k]["fmeasure"].append(s[k].fmeasure)

post_ft_scores_detailed = {
    rouge_name: {
        metric_name: round(float(np.mean(metric_values)) * 100, 4)
        for metric_name, metric_values in metrics_dict.items()
    }
    for rouge_name, metrics_dict in agg_post.items()
}

# Keep compatibility with downstream comparison cell (uses f-measure only)
post_ft_scores = {k: v["fmeasure"] for k, v in post_ft_scores_detailed.items()}

print("\n--- Post-fine-tuning ROUGE Scores (mean %, 250 test samples) ---")
for rouge_name, metrics_dict in post_ft_scores_detailed.items():
    print(
        f"  {rouge_name:6s} -> "
        f"precision: {metrics_dict['precision']:.4f}, "
        f"recall: {metrics_dict['recall']:.4f}, "
        f"fmeasure: {metrics_dict['fmeasure']:.4f}"
    )

# Compute BERTScore for post-fine-tuning generated summaries
print(f"\nComputing BERTScore for post-fine-tuning summaries ({BASELINE_SAMPLE_SIZE} samples)...")
post_ft_bs = bert_score.score(
    cands=post_ft_generated,
    refs=baseline_sample["summary"].tolist(),
    lang="id",
    verbose=True,
    batch_size=64,
)

post_ft_bertscore = {
    "precision": round(float(post_ft_bs[0].mean()) * 100, 4),
    "recall": round(float(post_ft_bs[1].mean()) * 100, 4),
    "f1": round(float(post_ft_bs[2].mean()) * 100, 4),
}

print(f"\n--- Post-fine-tuning BERTScore (mean %, {BASELINE_SAMPLE_SIZE} test samples) ---")
print(f"  Precision: {post_ft_bertscore['precision']:.4f}")
print(f"  Recall:    {post_ft_bertscore['recall']:.4f}")
print(f"  F1:        {post_ft_bertscore['f1']:.4f}")
# Out:
# Generating post-fine-tuning summaries on the same 250 baseline test samples...
# Done. Generated 250 summaries.
#
# --- Post-fine-tuning ROUGE Scores (mean %, 250 test samples) ---
#   rouge1 -> precision: 35.1484, recall: 25.8358, fmeasure: 29.3378
#   rouge2 -> precision: 14.9703, recall: 10.8727, fmeasure: 12.3918
#   rougeL -> precision: 30.1483, recall: 22.0735, fmeasure: 25.1168
#
# Computing BERTScore for post-fine-tuning summaries (250 samples)...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-base-multilingual-cased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/8 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 0.26 seconds, 964.45 sentences/sec
#
# --- Post-fine-tuning BERTScore (mean %, 250 test samples) ---
#   Precision: 73.9012
#   Recall:    70.6456
#   F1:        72.2133

# %% [markdown]
# ### 10c) Novel N-gram Ratio on Generated Summaries
# Compare abstractiveness on the same baseline subset by measuring how much of each summary uses n-grams not found in the source article. This helps explain cases where ROUGE improves but human-perceived quality does not.

# %%
def mean_novel_ngram_ratio(articles, summaries, n):
    ratios = [
        novel_ngram_ratio(article, summary, n)
        for article, summary in zip(articles, summaries)
        if pd.notna(article) and pd.notna(summary)
    ]
    ratios = pd.Series(ratios).dropna()
    return float(ratios.mean()) if len(ratios) else np.nan

subset_articles = baseline_sample['article'].tolist()
subset_references = baseline_sample['summary'].tolist()
subset_extractive = [reconstruct_extractive_from_indices(row_id) for row_id in baseline_sample['id'].tolist()]
subset_pre_ft = pre_ft_generated
subset_post_ft = post_ft_generated

novel_eval_rows = {}
for label, summaries in {
    'Reference summary': subset_references,
    'Extractive baseline': subset_extractive,
    'BERT2BERT pre-fine-tuning': subset_pre_ft,
    'BERT2BERT post-fine-tuning': subset_post_ft,
}.items():
    novel_eval_rows[label] = {
        f'Novel-{n}': round(mean_novel_ngram_ratio(subset_articles, summaries, n) * 100, 2)
        for n in [1, 2, 3, 4]
    }

novel_eval_df = pd.DataFrame(novel_eval_rows).T
print('Novel N-gram Ratio Comparison (% of summary n-grams not found in source article)')
display(novel_eval_df)

print('\nInterpretation: lower values indicate more extractive behavior; higher values indicate more abstractive phrasing.')
# Out:
# Novel N-gram Ratio Comparison (% of summary n-grams not found in source article)
#                             Novel-1  Novel-2  Novel-3  Novel-4
# Reference summary             15.12    51.06    70.26    81.33
# Extractive baseline            0.00     0.01     2.24     4.68
# BERT2BERT pre-fine-tuning     22.25    45.89    61.51    72.12
# BERT2BERT post-fine-tuning    20.44    42.92    58.91    70.75
# Interpretation: lower values indicate more extractive behavior; higher values indicate more abstractive phrasing.

# %% [markdown]
# ## 11) Comparison Table & Qualitative Demo
#
# ### 11a) ROUGE & BERTScore Comparison Tables
# Compare our model (before and after fine-tuning) against the paper's published baselines on the Liputan6 canonical test set.
# - **ROUGE** measures n-gram overlap (lexical similarity).
# - **BERTScore** measures semantic similarity via contextual embeddings — captures paraphrases and morphological variants that ROUGE misses.
#
# ### 11b) Qualitative Examples
# Inspect sample articles side-by-side: reference summary, pre-fine-tuned output, and post-fine-tuned output.

# %%
import json
import pandas as pd
import numpy as np
from rouge_score import rouge_scorer as rs

# Paper-reported baselines on the canonical test set (Table 3, AACL 2020 paper)
paper_baselines = {
    "Lead-2 (paper)":              {"rouge1": 36.68, "rouge2": 20.23, "rougeL": 33.71},
    "PTGen (paper)":               {"rouge1": 36.10, "rouge2": 19.19, "rougeL": 33.56},
    "BertAbs mBERT (paper)":       {"rouge1": 39.48, "rouge2": 21.59, "rougeL": 36.72},
    "BertExtAbs mBERT (paper)":    {"rouge1": 39.81, "rouge2": 21.84, "rougeL": 37.02},
    "BertAbs IndoBERT (paper)":    {"rouge1": 40.94, "rouge2": 23.01, "rougeL": 37.89},
    "BertExtAbs IndoBERT (paper) ★": {"rouge1": 41.08, "rouge2": 22.85, "rougeL": 38.01},
}

def normalize_extractive_summary(value):
    """Normalize non-index extractive_summary values into plain text."""
    if isinstance(value, str):
        return value.strip()

    if isinstance(value, list):
        chunks = []
        for item in value:
            if isinstance(item, list):
                chunks.append(" ".join(str(tok) for tok in item))
            else:
                chunks.append(str(item))
        return " ".join(part for part in chunks if part).strip()

    if pd.isna(value):
        return ""

    return str(value).strip()

def _resolve_row_id(raw_id):
    """Convert id values from dataframe into canonical filename stem."""
    if isinstance(raw_id, (int, np.integer)):
        return str(int(raw_id))
    if isinstance(raw_id, float) and raw_id.is_integer():
        return str(int(raw_id))
    return str(raw_id).strip()

def reconstruct_extractive_from_indices(row_id):
    """Rebuild extractive summary text from clean_article sentence indices in test JSON."""
    json_id = _resolve_row_id(row_id)
    json_path = base_dir / "test" / f"{json_id}.json"

    if not json_path.exists():
        return ""

    with open(json_path, "r", encoding="utf-8") as f:
        sample = json.load(f)

    clean_article = sample.get("clean_article", [])
    extractive = sample.get("extractive_summary", [])

    # Primary path: extractive_summary is a list of sentence indices into clean_article.
    if isinstance(extractive, list) and all(isinstance(i, (int, np.integer)) for i in extractive):
        sentence_texts = [
            " ".join(sent) if isinstance(sent, list) else str(sent)
            for sent in clean_article
        ]
        picked = [sentence_texts[i] for i in extractive if 0 <= i < len(sentence_texts)]
        return " ".join(picked).strip()

    # Fallback if a sample stores extractive content in text/list form.
    return normalize_extractive_summary(extractive)

# New baseline: dataset-provided extractive summary on the same baseline subset
# NOTE: use_stemmer=False to match paper's pyrouge evaluation protocol
scorer_cmp = rs.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=False)
extractive_preds = [reconstruct_extractive_from_indices(row_id) for row_id in baseline_sample["id"].tolist()]

agg_ext = {"rouge1": [], "rouge2": [], "rougeL": []}
for pred, ref in zip(extractive_preds, baseline_sample["summary"].tolist()):
    s = scorer_cmp.score(target=ref, prediction=pred)
    for k in agg_ext:
        agg_ext[k].append(s[k].fmeasure)

extractive_scores = {k: round(float(np.mean(v)) * 100, 2) for k, v in agg_ext.items()}

# Our model results on the same 250-sample baseline subset
our_results = {
    "Extractive summary (baseline subset)": {k: extractive_scores[k] for k in ["rouge1", "rouge2", "rougeL"]},
    "BERT2BERT (pre-fine-tuning)":         {k: pre_ft_scores[k] for k in ["rouge1", "rouge2", "rougeL"]},
    "BERT2BERT (fine-tuned)":         {k: post_ft_scores[k] for k in ["rouge1", "rouge2", "rougeL"]},
}

all_results = {**paper_baselines, **our_results}
comparison_df = pd.DataFrame(all_results).T.rename(columns={
    "rouge1": "ROUGE-1", "rouge2": "ROUGE-2", "rougeL": "ROUGE-L"
})
comparison_df = comparison_df.round(2)

print("=" * 60)
print("ROUGE Comparison — Liputan6 Canonical Test Set")
print("(Paper baselines: full ~10,972 test samples;")
print(" Our model + extractive baseline: same 250 sampled test articles)")
print("=" * 60)
display(comparison_df)

# --- BERTScore Comparison Table ---
# Compute BERTScore for extractive baseline too
print("\nComputing BERTScore for extractive baseline...")
ext_bs = bert_score.score(
    cands=extractive_preds,
    refs=baseline_sample["summary"].tolist(),
    lang="id",
    verbose=False,
    batch_size=64,
)
ext_bertscore = {
    "precision": round(float(ext_bs[0].mean()) * 100, 4),
    "recall": round(float(ext_bs[1].mean()) * 100, 4),
    "f1": round(float(ext_bs[2].mean()) * 100, 4),
}

bertscore_results = {
    "Extractive summary (baseline subset)": ext_bertscore,
    "BERT2BERT (pre-fine-tuning)":         pre_ft_bertscore,
    "BERT2BERT (fine-tuned ours)":         post_ft_bertscore,
}

bertscore_df = pd.DataFrame(bertscore_results).T.rename(columns={
    "precision": "BS-Precision", "recall": "BS-Recall", "f1": "BS-F1"
})
bertscore_df = bertscore_df.round(2)

print("\n" + "=" * 60)
print("BERTScore Comparison — Liputan6 Canonical Test Subset")
print(f"(Same {BASELINE_SAMPLE_SIZE} sampled test articles, lang='id')")
print("BS = BERTScore. Measures semantic similarity via embeddings,")
print("complementing ROUGE's n-gram overlap metric.")
print("=" * 60)
display(bertscore_df)
# Out:
# ============================================================
# ROUGE Comparison — Liputan6 Canonical Test Set
# (Paper baselines: full ~10,972 test samples;
#  Our model + extractive baseline: same 250 sampled test articles)
# ============================================================
#                                       ROUGE-1  ROUGE-2  ROUGE-L
# Lead-2 (paper)                          36.68    20.23    33.71
# PTGen (paper)                           36.10    19.19    33.56
# BertAbs mBERT (paper)                   39.48    21.59    36.72
# BertExtAbs mBERT (paper)                39.81    21.84    37.02
# BertAbs IndoBERT (paper)                40.94    23.01    37.89
# BertExtAbs IndoBERT (paper) ★           41.08    22.85    38.01
# Extractive summary (baseline subset)    51.26    30.44    41.34
# BERT2BERT (pre-fine-tuning)             28.05    12.36    23.64
# BERT2BERT (fine-tuned)                  29.34    12.39    25.12
# Computing BERTScore for extractive baseline...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-base-multilingual-cased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ============================================================
# BERTScore Comparison — Liputan6 Canonical Test Subset
# (Same 250 sampled test articles, lang='id')
# BS = BERTScore. Measures semantic similarity via embeddings,
# complementing ROUGE's n-gram overlap metric.
# ============================================================
#                                       BS-Precision  BS-Recall  BS-F1
# Extractive summary (baseline subset)         76.76      82.21  79.34
# BERT2BERT (pre-fine-tuning)                  74.82      71.93  73.32
# BERT2BERT (fine-tuned ours)                  73.90      70.65  72.21

# %%
DEMO_N = 10

print("=" * 80)
print(f"Qualitative Demo — {DEMO_N} Sample Summaries")
print("=" * 80)

for i in range(DEMO_N):
    row = baseline_sample.iloc[i]
    # Truncate article preview to first 300 chars to keep output readable
    article_preview = row["article"][:300].rsplit(" ", 1)[0] + " ..."

    print(f"\n[Sample {i+1}]")
    print(f"  Article (first 300 chars):\n    {article_preview}")
    print(f"\n  Reference Summary:\n    {row['summary']}")
    print(f"\n  Pre-fine-tuning Generated:\n    {pre_ft_generated[i]}")
    print(f"\n  Post-fine-tuning Generated:\n    {post_ft_generated[i]}")
    print("-" * 80)
# Out:
# ================================================================================
# Qualitative Demo — 10 Sample Summaries
# ================================================================================
#
# [Sample 1]
#   Article (first 300 chars):
#     Liputan6 . com , Manggarai : Ada banyak cara untuk mensyukuri nikmat yang telah diberikan oleh Tuhan , Sang Maha Pemurah . Dalam kehidupan masyarakat agraris , tradisi syukuran seperti itu bukan hal yang aneh , apalagi setelah musim panen tiba . Di Pulau Flores , Nusatenggara Timur , suku Manggarai ...
#
#   Reference Summary:
#     Suku Manggarai di Pulau Flores , NTT , memiliki beragam upacara ritual sebagai ucapan syukur atas rahmat Sang Kuasa . Sebagian besar masyarakatnya tetap mempertahankan budaya itu .
#
#   Pre-fine-tuning Generated:
#     masyarakat agraris memiliki sederet upacara ritual sebagai ucapan syukur atas nikmat yang telah dijalani dalam periode tertentu.
#
#   Post-fine-tuning Generated:
#     ,, memiliki sederet upacara ritual sebagai ucapan syukur atas nikmat yang diberikan oleh. ritual ini juga dijadikan momentum reuni keluarga suku.
# --------------------------------------------------------------------------------
#
# [Sample 2]
#   Article (first 300 chars):
#     Liputan6 . com , Jakarta : Penyelenggaraan Sidang Istimewa MPR tinggal lima pekan lagi . Presiden Abdurrahman Wahid juga telah meminta anggota MPR untuk tak mengagendakan pertanggungjawabannya . Menurut ahli hukum tata negara Universitas Airlangga Susanto Muljosudarno , intervensi Gus Dur itu ...
#
#   Reference Summary:
#     Presiden Abdurrahman Wahid meminta MPR tak meminta pertanggungjawabannya dalam Sidang Istimewa MPR . Permintaan Gus Dur dinilai sebagai kekerasan politik dalam bentuk simbolik .
#
#   Pre-fine-tuning Generated:
#     pengamat hukum tata negara mengatakan, kekerasan politik dalam bentuk simbolik adalah bentuk kekerasan politik. persyaratan yang harus dipenuhi adalah mempersiapkan pertanggungjawaban.
#
#   Post-fine-tuning Generated:
#     hukum tata negara mengatakan, intervensi adalah kekerasan politik dalam bentuk simbolik. tak boleh mencampuri agenda sidang.
# --------------------------------------------------------------------------------
#
# [Sample 3]
#   Article (first 300 chars):
#     Liputan6 . com , Jakarta : Polemik rencana kenaikan tarif bahan bakar minyak pada 15 Juni mendatang masih berlangsung . Dalam pembahasan Anggaran Pendapatan dan Belanja Negara 2001 , di Gedung DPR , Rabu ( 6/06 ) siang , Komisi VIII DPR merekomendasikan kenaikan tarif BBM , rata-rata sebesar 27 ...
#
#   Reference Summary:
#     Panitia Anggaran DPR masih belum menyetujui kenaikan tarif BBM yang rata-rata sebesar 27 persen . Kenaikan harga BBM pada pertengahan Juni mendatang dikhawatirkan mematikan sebagian pengusaha kecil dan menengah .
#
#   Pre-fine-tuning Generated:
#     pemerintah tak bisa menunjukkan data yang benar mengenai tingkat konsumsi bahan bakar minyak. bila data tak akurat, dikhawatirkan subsidi menjadi tidak efisien dan tetap memberi peluang penyelundupan.
#
#   Post-fine-tuning Generated:
#     rencana pemerintah menaikkan tarif, rata - rata sebesar 27 persen., pemerintah tak bisa menunjukkan data yang benar mengenai tingkat konsumsi dari.
# --------------------------------------------------------------------------------
#
# [Sample 4]
#   Article (first 300 chars):
#     Liputan6 . com , Jakarta : Instruksi Presiden Megawati Sukarnoputri kepada Tentara Nasional Indonesia agar tidak berpolitik praktis seharusnya segera diikuti dengan dasar legal . Hal itu diperlukan agar TNI bisa segera merealisasikan kebijakan tersebut . Demikian diutarakan pengamat militer ...
#
#   Reference Summary:
#     Instruksi kepada TNI untuk tak berpolitik praktis mestinya diikuti dengan dasar legal agar kebijakan itu dapat terealisir . Pemerintah diminta segera mengajukan RUU yang dapat memperjelas fungsi TNI .
#
#   Pre-fine-tuning Generated:
#     pengamat militer meminta agar pemerintah segera merealisasikan keinginan mereka untuk keluar dari politik praktis.
#
#   Post-fine-tuning Generated:
#     meminta agar segera merealisasikan keinginan keluar dari politik praktis., keinginan itu dilihat dari keberadaan militer dalam.
# --------------------------------------------------------------------------------
#
# [Sample 5]
#   Article (first 300 chars):
#     Liputan6 . com , Jakarta : Bentrokan terjadi antara warga Cikini Ampiun dan Jalan Anyer di kawasan Megaria Menteng , Jakarta Pusat , Sabtu ( 1/12 ) dini hari . Di tempat kejadian , polisi menemukan sejumlah paku panah . Menurut Kepala Kepolisian Sektor Menteng Eky Febriyanto , bentrokan terjadi ...
#
#   Reference Summary:
#     Sejumlah warga Cikini dan Jalan Anyer terlibat aksi baku hantam . Sejumlah organisasi Islam yang berunjuk rasa menuntut penutupan tempat hiburan malam merusak sebuah kafe di Tanjungpriok .
#
#   Pre-fine-tuning Generated:
#     dipicu kecemburuan sosial, bentrokan antara warga elite di kawasan elite senayan dini hari tadi.
#
#   Post-fine-tuning Generated:
#     terjadi antara warga dan di kawasan,, dini hari tadi. bentrok dipicu kecemburuan sosial.
# --------------------------------------------------------------------------------
#
# [Sample 6]
#   Article (first 300 chars):
#     Liputan6 . com , Pekanbaru : Masyarakat Pekanbaru , Riau , mempunyai minuman khas setiap Ramadan . Namanya unik , Laksamana Mengamuk . Meski namanya terkesan galak , minuman yang tak ditemukan di hari-hari biasa ini mempunyai cita rasa manis . Pada Ramadan 1422 Hijriah ini , sejumlah pedagang ...
#
#   Reference Summary:
#     Laksamana Mengamuk adalah minuman khas masyarakat Riau setiap Ramadan . Konon , minuman ini sudah ada sejak zaman Kerajaan Melayu Riau .
#
#   Pre-fine-tuning Generated:
#     buah kwini tak hanya ditemukan di hari - hari biasa. penjual minuman ini juga sibuk berjualan minuman pembuka puasa.
#
#   Post-fine-tuning Generated:
#     ,, mempunyai minuman khas setiap. namanya galak, minuman yang tak ditemukan di hari - hari biasa ini mempunyai cita rasa manis dan menggoda.
# --------------------------------------------------------------------------------
#
# [Sample 7]
#   Article (first 300 chars):
#     Liputan6 . com , Jakarta : Badan Penyehatan Perbankan Nasional ( BPPN ) akan menjual aset inti korporasi tahap keempat dengan mekanisme lelang terbuka yang dimulai 17 September hingga 30 November mendatang . Dalam lelang tersebut , ditawarkan aset delapan debitur dengan total portofolio kredit ...
#
#   Reference Summary:
#     Untuk memenuhi target setoran Rp 42 , 5 triliun , BPPN akan menjual aset inti korporasi . Hingga November mendatang , BPPN diperkirakan menyetor Rp 18 , 25 triliun .
#
#   Pre-fine-tuning Generated:
#     aset inti korporasi tahap keempat akan dijual dengan mekanisme lelang terbuka mulai 17 hingga 30 september mendatang.
#
#   Post-fine-tuning Generated:
#     akan menjual aset inti korporasi tahap keempat dengan mekanisme lelang terbuka mulai 17 hingga 30 mendatang. juga menawarkan program penjualan langsung terhadap portofolio kredit korporasi.
# --------------------------------------------------------------------------------
#
# [Sample 8]
#   Article (first 300 chars):
#     Liputan6 . com , Ambon : Berkaitan dengan ledakan bom di dalam bus Pemerintah Daerah Tingkat II Ambon , Maluku , Kepolisian Resor setempat memeriksa dua saksi yang di antaranya pegawai Departemen Pendidikan Nasional Maluku , Senin ( 31/12 ) siang . Sebelumnya , polisi juga telah memanggil seorang ...
#
#   Reference Summary:
#     Dua saksi kasus peledakan bom dalam bus Pemda Tingkat II Ambon , Maluku , diperiksa Polres setempat . Seorang di antaranya pegawai Depdiknas Maluku . Hingga kini pelaku belum terungkap .
#
#   Pre-fine-tuning Generated:
#     polisi memeriksa dua saksi yang diperiksa terkait peledakan bom di dalam bus. polisi mengimbau masyarakat agar membantu polisi.
#
#   Post-fine-tuning Generated:
#     yang berkekuatan sedang itu meledak dalam bus yang berada di samping setempat di,. seorang saksi diperiksa guna dimintai keterangan.
# --------------------------------------------------------------------------------
#
# [Sample 9]
#   Article (first 300 chars):
#     Liputan6 . com , Jakarta : Belasan rumah hangus terbakar di kawasan pemukiman Kelurahan Tanah Sereal , Jakarta Pusat , Selasa ( 16/10 ) dini hari . Lima regu pemadam kebakaran kesulitan memadamkan api karena lokasi pemukiman di Jalan Pekapuran tiga yang padat . Akibatnya , api terus menghanguskan ...
#
#   Reference Summary:
#     Si Jago Merah kembali melalap belasan rumah di Kelurahan Tanah Sereal , Jakarta Pusat . Kebakaran tak mengakibatkan korban jiwa .
#
#   Pre-fine-tuning Generated:
#     sebuah rumah semipermanen di kawasan pemukiman padat di bekasi, jawa barat, hangus terbakar.
#
#   Post-fine-tuning Generated:
#     rumah hangus terbakar di kawasan pemukiman,. api sulit dipadamkan karena lokasi pemukiman di tiga yang padat.
# --------------------------------------------------------------------------------
#
# [Sample 10]
#   Article (first 300 chars):
#     Liputan6 . com , Jakarta : Sebanyak 600 karyawan , perawat , dan tenaga paramedis di Rumah Sakit Atma Jaya , Pluit , Jakarta Utara hingga Rabu ( 7/06 ) ini , masih menggelar mogok kerja . Dalam aksi yang dimulai sejak Sabtu pekan silam , mereka menyatakan menolak bekerja lantaran tuntutan belum ...
#
#   Reference Summary:
#     Aksi mogok ratusan karyawan Rumah Sakit Atma Jaya Pluit Jakarta masih terus berlangsung . Mereka tetap menuntut agar pengelolaan manajemen dikembalikan ke Yayasan Katholik Atma Jaya .
#
#   Pre-fine-tuning Generated:
#     ratusan karyawan, perawat, dan paramedis di, masih mogok kerja. mereka menolak otonomi yang diberikan kepada rumah sakit.
#
#   Post-fine-tuning Generated:
#     karyawan, perawat, dan paramedis di,, menolak bekerja lantaran tuntutan belum dipenuhi. pelayanan medis lumpuh total.
# --------------------------------------------------------------------------------
